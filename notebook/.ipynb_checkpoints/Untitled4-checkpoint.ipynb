# %%
using Pickle, JSON, CSV, DataFrames, BenchmarkTools, Distributed, FileIO, Pickle, Unmarshal
using NetPricing
using JuMP
using Gurobi

# %%
model = Model(() -> Gurobi.Optimizer(current_env())) # NetPricing.
set_optimizer_attribute(model, MOI.Silent(), silent)
set_optimizer_attribute(model, MOI.NumberOfThreads(), threads)

##########################################################################
prob_o = problem(first(forms_o))
prob_g = problem(first(forms_g))

# Big M
#Ms = [calculate_bigM(form, threads=threads) for form in forms]
NU = max.(collect.(maximum.(Ms, dims=2))...)

# Toll variables
a1 = tolled_arcs(prob_o)
a1dict = Dict(a => i for (i, a) in enumerate(a1))

# normal
@variable(model, 0 ≤ t[a=a1], upper_bound = NU[a1dict[a]])


# for each problem k
primal =... primal(form_k)
# Strong duality

    prob = problem(primal)
    parentprob = parent(prob)
    a1 = tolled_arcs(prob)
    k = index(prob)
    Amap = arcmap(prob)
    
    x = primal.x[a1]
    tx = @variable(model, [a=a1], lower_bound = 0, base_name="tx[$k]")
    t = remap_t(model, prob)
    
    if isempty(tx)
        sumtx = 0.0
    else
        sumtx = sum(tx)
    end

    @constraint(model, sumtx <= unnormalized_objective_term(form_k) + sdtol)












#a1dict = Dict(a => i for (i, a) in enumerate(tolled_arcs(parentprob)))
#mapped_a1 = [a1dict[a] for a in Amap[a1]]
#M = @view M[mapped_a1]
#N = @view N[mapped_a1]

# Linearization
#@constraint(model, tx .≤ M .* x)
#@constraint(model, t .- tx .≥ 0)
#@constraint(model, t .- tx .≤ N .* (1 .- x))

linearize_commodity_extra(linearization, primal)
#############################################################################












# Set objective function
@objective(model, Max, sum(objective_term.(forms))) # NetPricing.















# Dual de l'original (D)
dual = dual(forms_original)
prob = problem(dual)
nv = nodes(prob)
k = index(prob)
c = cost_vector(prob)
A = incidence_matrix(prob)
b = sourcesink_vector(prob)
λ = @variable(model, [1:nv], lower_bound = 0, base_name="λ[$k]")
fix_var(λ[dest(prob)])
t = remap_t(model, prob)
tfull = expand_t(t, prob)
@constraint(model, A' * λ .≤ c + tfull)

# Dual de la transformation (Dt)
dualt = dual(forms_gamma)
probt = problem(dualt)
nvt = nodes(probt)
kt = index(probt)
ct = cost_vector(probt)
At = incidence_matrix(probt)
bt = sourcesink_vector(probt)
λt = @variable(model, [1:nvt], lower_bound = 0, base_name="λt[$kt]")
fix_var(λt[dest(prob)])
tt = remap_t(model, probt)
ttfull = expand_t(tt, probt)
@constraint(model, At' * λt .≤ ct + ttfull)


## P >= Pt
@constraint(model, (ct + gamma(t))' * xt .≤ (c+t)' * x)

## D <= Dt
@constraint(model,  b' * λ .≤ bt' * λt)
